# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model import SimulacionModel

# %%
params = {'steps': 10, 'compradores':10, 'mercados':5}

# %%
model = SimulacionModel(params)

result = model.run()
# Out:
# Completed: 10 steps
# Run time: 0:00:00.004949
# Simulation finished

# %%
result.variables.SimulacionModel
# Out:
#     comprador_no_compra  mercado_gini              mercado_money  \
# t
# 0                    10      0.000000                       None
# 1                     0      0.015385                       None
# 2                     0      0.029630                       None
# 3                     0      0.043806                       None
# 4                     0      0.056944                       None
# 5                     0      0.074124                       None
# 6                     0      0.090032                       None
# 7                     0      0.105393                       None
# 8                     0      0.123529                       None
# 9                     0      0.139691                       None
# 10                    0      0.140761  [200, 145, 116, 100, 175]
#
#                     comprador_money               ventas   price_Manzanas  \
# t
# 0                              None                 None             None
# 1                              None                 None             None
# 2                              None                 None             None
# 3                              None                 None             None
# 4                              None                 None             None
# 5                              None                 None             None
# 6                              None                 None             None
# 7                              None                 None             None
# 8                              None                 None             None
# 9                              None                 None             None
# 10  [5, 5, 5, 5, 9, 9, 14, 5, 5, 2]  [44, 25, 12, 0, 36]  [5, 3, 2, 1, 4]
#
#                     items_Manzanas      price_Peras  \
# t
# 0                             None             None
# 1                             None             None
# 2                             None             None
# 3                             None             None
# 4                             None             None
# 5                             None             None
# 6                             None             None
# 7                             None             None
# 8                             None             None
# 9                             None             None
# 10  [1, 1, 0, 0, 1, 1, 1, 1, 0, 1]  [2, 1, 1, 1, 2]
#
#                        items_Peras
# t
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# 5                             None
# 6                             None
# 7                             None
# 8                             None
# 9                             None
# 10  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
