# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from model import SimulacionModel

# %%
params = {'steps': 10, 'compradores':10, 'mercados':5, 'distancia': 10, "c_threshold":1, "c_comer":1}

# %%
model = SimulacionModel(params)

result = model.run()
# Out:
# Completed: 10 steps
# Run time: 0:00:00.010432
# Simulation finished

# %%
result.variables.SimulacionModel
# Out:
#     comprador_no_compra  mercado_gini  \
# t
# 0                    10      0.000000
# 1                     8      0.004762
# 2                     8      0.008983
# 3                     8      0.012732
# 4                     8      0.016065
# 5                     8      0.019033
# 6                     8      0.021971
# 7                     8      0.024879
# 8                     8      0.027471
# 9                     8      0.029785
# 10                    8      0.031851
#
#                                 mercado_money  \
# t
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6                                        None
# 7                                        None
# 8                                        None
# ...

# %%
model.visualize()
